# %%
import topArtist
import process
import os

import pandas as pd
import matplotlib.pyplot as plt

# %%
file_name = 'spotifyData'

# %%
## Read in or process streaming data.  Process script will take the raw json files from spotify, combine and calculate extra variables.
if f'{file_name}.h5' not in os.listdir():
    data = process.process()
else:
    data = pd.read_hdf(f'{file_name}.h5', key='data')

data.columns
# Out:
# Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode', 'whichHour', 'whichWeekday', 'whichMonth',
#        'whichYear', 'played'],
#       dtype='object')

# %%
fig, ax = topArtist.artist_plot(data)
plt.show()
